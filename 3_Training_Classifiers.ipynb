# %% [markdown]
# ## Import all library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import mne
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import pywt 
from PIL import Image
from utility import *
from model import *
from torchsummary import summary
import torch.optim.lr_scheduler as lr_scheduler


MODEL_FILE_DIRC_SateLight = MODEL_FILE_DIRC + "/SateLight"
MODEL_FILE_DIRC_CNN       = MODEL_FILE_DIRC + "/CNN"
os.makedirs(MODEL_FILE_DIRC_CNN, exist_ok=True)
os.makedirs(MODEL_FILE_DIRC_SateLight, exist_ok=True)

torch.manual_seed(3407)

# %% [markdown]
# ## Data Preparation
# * Convert the data from csv to Dataloader

# %%
# %%time
eeg_num_list = list(range(1,41))

dataloaders, num_data = get_dataloader(eeg_num_list, shuffle=True, get_dataDWT=False)
    

num_train_data, num_valid_data, num_test_data = num_data
train_data, valid_data, test_data             = dataloaders
# Out:
# The data from EEG_csv/eeg1.csv is loaded
# There is no spike in this eeg file
# (252, 1280, 19)
# EEG1 has 252 windows of data
#
#
# The data from EEG_csv/eeg2.csv is loaded
# There is no spike in this eeg file
# (43, 1280, 19)
# EEG2 has 43 windows of data
#
#
# The data from EEG_csv/eeg3.csv is loaded
# There is no spike in this eeg file
# (88, 1280, 19)
# EEG3 has 88 windows of data
#
#
# The data from EEG_csv/eeg4.csv is loaded
# There is no spike in this eeg file
# (245, 1280, 19)
# EEG4 has 245 windows of data
#
#
# The data from EEG_csv/eeg5.csv is loaded
# There is no spike in this eeg file
# (236, 1280, 19)
# EEG5 has 236 windows of data
#
#
# The data from EEG_csv/eeg6.csv is loaded
# There is spike in this eeg file
# Data before split : (481920, 19)
# Data with spike   : (465280, 19)
# Data without spike: (16640, 19)
# Data after  split into window: (376, 1280, 19)
# Labels: (376,)
# Num spike: 13
# EEG6 has 376 windows of data
#
#
# The data from EEG_csv/eeg7.csv is loaded
# There is no spike in this eeg file
# (311, 1280, 19)
# EEG7 has 311 windows of data
#
#
# The data from EEG_csv/eeg8.csv is loaded
# There is no spike in this eeg file
# (243, 1280, 19)
# EEG8 has 243 windows of data
#
#
# The data from EEG_csv/eeg9.csv is loaded
# There is no spike in this eeg file
# (322, 1280, 19)
# EEG9 has 322 windows of data
#
#
# The data from EEG_csv/eeg10.csv is loaded
# There is no spike in this eeg file
# (422, 1280, 19)
# EEG10 has 422 windows of data
#
#
# The data from EEG_csv/eeg11.csv is loaded
# There is no spike in this eeg file
# (126, 1280, 19)
# EEG11 has 126 windows of data
#
#
# The data from EEG_csv/eeg12.csv is loaded
# There is no spike in this eeg file
# (48, 1280, 19)
# EEG12 has 48 windows of data
#
#
# The data from EEG_csv/eeg13.csv is loaded
# There is no spike in this eeg file
# (182, 1280, 19)
# EEG13 has 182 windows of data
#
#
# The data from EEG_csv/eeg14.csv is loaded
# There is no spike in this eeg file
# (217, 1280, 19)
# EEG14 has 217 windows of data
#
#
# The data from EEG_csv/eeg15.csv is loaded
# There is no spike in this eeg file
# (319, 1280, 19)
# EEG15 has 319 windows of data
#
#
# The data from EEG_csv/eeg16.csv is loaded
# There is no spike in this eeg file
# (58, 1280, 19)
# EEG16 has 58 windows of data
#
#
# The data from EEG_csv/eeg17.csv is loaded
# There is no spike in this eeg file
# (208, 1280, 19)
# EEG17 has 208 windows of data
#
#
# The data from EEG_csv/eeg18.csv is loaded
# There is no spike in this eeg file
# (313, 1280, 19)
# EEG18 has 313 windows of data
#
#
# The data from EEG_csv/eeg19.csv is loaded
# There is spike in this eeg file
# Data before split : (413568, 19)
# Data with spike   : (411008, 19)
# Data without spike: (2560, 19)
# Data after  split into window: (323, 1280, 19)
# Labels: (323,)
# Num spike: 2
# EEG19 has 323 windows of data
#
#
# The data from EEG_csv/eeg20.csv is loaded
# There is no spike in this eeg file
# (255, 1280, 19)
# EEG20 has 255 windows of data
#
#
# The data from EEG_csv/eeg21.csv is loaded
# There is no spike in this eeg file
# (363, 1280, 19)
# EEG21 has 363 windows of data
#
#
# The data from EEG_csv/eeg22.csv is loaded
# There is no spike in this eeg file
# (15, 1280, 19)
# EEG22 has 15 windows of data
#
#
# The data from EEG_csv/eeg23.csv is loaded
# There is no spike in this eeg file
# (308, 1280, 19)
# EEG23 has 308 windows of data
#
#
# The data from EEG_csv/eeg24.csv is loaded
# There is spike in this eeg file
# Data before split : (386560, 19)
# Data with spike   : (385280, 19)
# Data without spike: (1280, 19)
# Data after  split into window: (302, 1280, 19)
# Labels: (302,)
# Num spike: 1
# EEG24 has 302 windows of data
#
#
# The data from EEG_csv/eeg25.csv is loaded
# There is no spike in this eeg file
# (426, 1280, 19)
# EEG25 has 426 windows of data
#
#
# The data from EEG_csv/eeg26.csv is loaded
# There is no spike in this eeg file
# (237, 1280, 19)
# EEG26 has 237 windows of data
#
#
# The data from EEG_csv/eeg27.csv is loaded
# There is no spike in this eeg file
# (147, 1280, 19)
# EEG27 has 147 windows of data
#
#
# The data from EEG_csv/eeg28.csv is loaded
# There is no spike in this eeg file
# (173, 1280, 19)
# EEG28 has 173 windows of data
#
#
# The data from EEG_csv/eeg29.csv is loaded
# There is no spike in this eeg file
# (29, 1280, 19)
# EEG29 has 29 windows of data
#
#
# The data from EEG_csv/eeg30.csv is loaded
# There is no spike in this eeg file
# (300, 1280, 19)
# EEG30 has 300 windows of data
#
#
# The data from EEG_csv/eeg31.csv is loaded
# There is spike in this eeg file
# Data before split : (381312, 19)
# Data with spike   : (341632, 19)
# Data without spike: (39680, 19)
# Data after  split into window: (297, 1280, 19)
# Labels: (297,)
# Num spike: 31
# EEG31 has 297 windows of data
#
#
# The data from EEG_csv/eeg32.csv is loaded
# There is no spike in this eeg file
# (254, 1280, 19)
# EEG32 has 254 windows of data
#
#
# The data from EEG_csv/eeg33.csv is loaded
# There is no spike in this eeg file
# (65, 1280, 19)
# EEG33 has 65 windows of data
#
#
# The data from EEG_csv/eeg34.csv is loaded
# There is no spike in this eeg file
# (264, 1280, 19)
# EEG34 has 264 windows of data
#
#
# The data from EEG_csv/eeg35.csv is loaded
# There is no spike in this eeg file
# (297, 1280, 19)
# EEG35 has 297 windows of data
#
#
# The data from EEG_csv/eeg36.csv is loaded
# There is spike in this eeg file
# Data before split : (344448, 19)
# Data with spike   : (313728, 19)
# Data without spike: (30720, 19)
# Data after  split into window: (269, 1280, 19)
# Labels: (269,)
# Num spike: 24
# EEG36 has 269 windows of data
#
#
# The data from EEG_csv/eeg37.csv is loaded
# There is no spike in this eeg file
# (300, 1280, 19)
# EEG37 has 300 windows of data
#
#
# The data from EEG_csv/eeg38.csv is loaded
# There is no spike in this eeg file
# (94, 1280, 19)
# EEG38 has 94 windows of data
#
#
# The data from EEG_csv/eeg39.csv is loaded
# There is spike in this eeg file
# Data before split : (55296, 19)
# Data with spike   : (54016, 19)
# Data without spike: (1280, 19)
# Data after  split into window: (43, 1280, 19)
# Labels: (43,)
# Num spike: 1
# EEG39 has 43 windows of data
#
#
# The data from EEG_csv/eeg40.csv is loaded
# There is no spike in this eeg file
# (291, 1280, 19)
# EEG40 has 291 windows of data
#
#
# > > > Train    data  has shape: torch.Size([6345, 19, 1280]) when duration = 10 seconds
# > > > Data after DWT has shape: torch.Size([6345, 19, 1282])
# > > > Label              shape: torch.Size([6345])
# CPU times: total: 2min 39s
# Wall time: 1min 53s

# %% [markdown]
# ## Function to train the model

# %%
def start_classification_model_training(EPOCH_START, NUM_EPOCHS_CLASSIFIER, 
                                        model, MODEL_FILE_DIRC, model_name,  
                                        df, prev_best_valid_f1,prev_best_valid_loss,
                                        train_data, num_train_data, 
                                        valid_data, num_valid_data, 
                                        scheduler, optimizer, device):
    count = 0
    for epoch in range(EPOCH_START, NUM_EPOCHS_CLASSIFIER):
        
            ## 1. Training
            model.train()
            train_loss, train_metric = train_classifier(model, train_data, device, num_train_data, optimizer) 
            
            ## 2. Evaluating
            model.eval()
            valid_loss, valid_metric = evaluate_classifier(model, valid_data, device, num_valid_data) 
            
            ## 3. Show the result
            list_data       = [train_loss, valid_loss]
            for key in ["precision", "accuracy", "f1_score", "recall"]:
                list_data.append(train_metric[key])
                list_data.append(valid_metric[key])
            df.loc[len(df)] = list_data
            
            print_log(f"> > > Epoch     : {epoch}", MODEL_FILE_DIRC)
            print_log(f"Train {'loss':<10}: {train_loss}", MODEL_FILE_DIRC)
            print_log(f"Valid {'loss':<10}: {valid_loss}", MODEL_FILE_DIRC)
            for key in ["precision", "accuracy", "f1_score", "recall"]:
                print_log(f"Train {key:<10}: {train_metric[key]}", MODEL_FILE_DIRC)
                print_log(f"Valid {key:<10}: {valid_metric[key]}", MODEL_FILE_DIRC)

            
            ## 3.1 Plot the loss function
            fig,ax = plt.subplots(3,2, figsize=(10,10))
            x_data = range(len(df["Train Loss"]))
            for i, key in enumerate(["Loss","precision", "accuracy", "f1_score", "recall"]):    
                ax[i%3][i//3].plot(x_data, df[f"Train {key}"], label=f"Train {key}")
                ax[i%3][i//3].plot(x_data, df[f"Valid {key}"], label=f"Valid {key}")
                ax[i%3][i//3].legend()
            plt.savefig(f'{MODEL_FILE_DIRC}/Loss.png', transparent=False, facecolor='white')
            plt.close('all')

            ## 3.3. Save model and Stoping criteria
            if prev_best_valid_f1 <= valid_metric["f1_score"]:  # If previous best validation f1-score <= current f1-score 
                state_dict = {
                    "model": model.state_dict(), 
                    "epoch":epoch,
                    "valid_f1_score": valid_metric["f1_score"],
                    "valid_loss": valid_loss
                }
                torch.save(state_dict, f"{MODEL_FILE_DIRC}/{model_name}_best.pt")
                prev_best_valid_f1 = valid_metric["f1_score"]  # Previous validation loss = Current validation loss
                count = 0
            else:
                count += 1
            
            if epoch % 5 == 0:
                state_dict = {
                    "model": model.state_dict(), 
                    "epoch":epoch,
                    "valid_f1_score": valid_metric["f1_score"],
                    "valid_loss": valid_loss
                }
                torch.save(state_dict, f"{MODEL_FILE_DIRC}/{model_name}_{epoch}.pt")
            
            df.to_csv(f"{MODEL_FILE_DIRC}/Loss.csv", index=False)
            
            if count == MAX_COUNT_F1_SCORE:
                print_log(f"The validation f1 score is not increasing for continuous {MAX_COUNT_F1_SCORE} time, so training stop", MODEL_FILE_DIRC)
                break
            
            scheduler.step()

# %%
def load_classification_model_dict(model, MODEL_FILE_DIRC, model_name):
    list_model = os.listdir(MODEL_FILE_DIRC) 
    if len(list_model) > 0:    # Load the latest trained model
        if os.path.exists(f"{MODEL_FILE_DIRC}/{model_name}_best.pt"):
            state_dict_loaded    = torch.load(f"{MODEL_FILE_DIRC}/{model_name}_best.pt")
            prev_best_valid_f1   = state_dict_loaded["valid_f1_score"]
            prev_best_valid_loss = state_dict_loaded["valid_loss"]
        list_model.remove(f"{model_name}_best.pt")
        num_list   = [int(model_dir[model_dir.rindex("_") +1: model_dir.rindex(".")]) for model_dir in list_model if model_dir.endswith(".pt")]
        num_max    = np.max(num_list)
        
        state_dict_loaded = torch.load(f"{MODEL_FILE_DIRC}/{model_name}_{num_max}.pt")
        model.load_state_dict(state_dict_loaded["model"])
        EPOCH_START = state_dict_loaded["epoch"] + 1
        
        print(f"The model has been loaded from the file '{model_name}_{num_max}.pt'")

        if os.path.exists(f"{MODEL_FILE_DIRC}/Loss.csv"):
            df = pd.read_csv(f"{MODEL_FILE_DIRC}/Loss.csv")
            df = df.iloc[:EPOCH_START-1, :]
            print(f"The dataframe that record the loss have been loaded from {MODEL_FILE_DIRC}/Loss.csv")

    else:
        EPOCH_START            = 1
        prev_best_valid_f1     = -1
        prev_best_valid_loss   = 10000
        df                     = pd.DataFrame(columns = ["Train Loss", "Valid Loss"] + \
                                                         flatten_concatenation([[f"Train {metric}", f"Valid {metric}"] for metric in ["precision", "accuracy", "f1_score", "recall"]]) )
    return model, df, EPOCH_START, prev_best_valid_f1, prev_best_valid_loss

# %% [markdown]
# ## Build and Train the SateLight model

# %% [markdown]
# ### Build the SateLight model

# %%
model      = SateLight().to(device)
optimizer  = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# Get the following information:
# 1. Previous Trained model (if exist)
# 2. df that store the training/validation loss & metrics
# 3. epoch where the training start
# 4. Previous Highest Validation F1-score
# 5. Previous Lowest  Validation Loss
model, df, EPOCH_START, prev_best_valid_f1, prev_best_valid_loss = load_classification_model_dict(model, MODEL_FILE_DIRC_SateLight, "SateLight")

# Get the summary of the model
print(summary(model, (19,1280)))
# Out:
# The model has been loaded from the file 'SateLight_25.pt'
# The dataframe that record the loss have been loaded from Model/SateLight/Loss.csv
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Sequential: 1-1                             [-1, 32, 1, 641]          --
# |    └─Conv2d: 2-1                            [-1, 16, 19, 641]         10,256
# |    └─Conv2d: 2-2                            [-1, 32, 1, 641]          640
# ├─BatchNorm1d: 1-2                            [-1, 32, 641]             64
# ├─ReLU: 1-3                                   [-1, 32, 641]             --
# ├─Dropout: 1-4                                [-1, 32, 641]             --
# ├─MaxPool1d: 1-5                              [-1, 32, 160]             --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-3                        [-1, 160, 32]             --
# |    |    └─SelfAttention: 3-1                [-1, 160, 32]             7,392
# |    |    └─BatchNorm1d: 3-2                  [-1, 160, 32]             320
# |    |    └─Dropout: 3-3                      [-1, 160, 32]             --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-4                        [-1, 160, 64]             --
# |    |    └─Linear: 3-4                       [-1, 160, 64]             2,112
# |    |    └─BatchNorm1d: 3-5                  [-1, 160, 64]             320
# |    |    └─ReLU: 3-6                         [-1, 160, 64]             --
# |    |    └─Dropout: 3-7                      [-1, 160, 64]             --
# ├─MaxPool1d: 1-6                              [-1, 64, 40]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-5                        [-1, 40, 64]              --
# |    |    └─SelfAttention: 3-8                [-1, 40, 64]              29,120
# |    |    └─BatchNorm1d: 3-9                  [-1, 40, 64]              80
# |    |    └─Dropout: 3-10                     [-1, 40, 64]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-6                        [-1, 40, 96]              --
# |    |    └─Linear: 3-11                      [-1, 40, 96]              6,240
# |    |    └─BatchNorm1d: 3-12                 [-1, 40, 96]              80
# |    |    └─ReLU: 3-13                        [-1, 40, 96]              --
# |    |    └─Dropout: 3-14                     [-1, 40, 96]              --
# ├─MaxPool1d: 1-7                              [-1, 96, 10]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-7                        [-1, 10, 96]              --
# |    |    └─SelfAttention: 3-15               [-1, 10, 96]              65,184
# |    |    └─BatchNorm1d: 3-16                 [-1, 10, 96]              20
# |    |    └─Dropout: 3-17                     [-1, 10, 96]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-8                        [-1, 10, 128]             --
# |    |    └─Linear: 3-18                      [-1, 10, 128]             12,416
# |    |    └─BatchNorm1d: 3-19                 [-1, 10, 128]             20
# |    |    └─ReLU: 3-20                        [-1, 10, 128]             --
# |    |    └─Dropout: 3-21                     [-1, 10, 128]             --
# ├─MaxPool1d: 1-8                              [-1, 128, 2]              --
# ├─Linear: 1-9                                 [-1, 1]                   257
# ===============================================================================================
# Total params: 134,521
# Trainable params: 134,521
# Non-trainable params: 0
# Total mult-adds (M): 125.46
# ===============================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 2.30
# Params size (MB): 0.51
# Estimated Total Size (MB): 2.90
# ===============================================================================================
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Sequential: 1-1                             [-1, 32, 1, 641]          --
# |    └─Conv2d: 2-1                            [-1, 16, 19, 641]         10,256
# |    └─Conv2d: 2-2                            [-1, 32, 1, 641]          640
# ├─BatchNorm1d: 1-2                            [-1, 32, 641]             64
# ├─ReLU: 1-3                                   [-1, 32, 641]             --
# ├─Dropout: 1-4                                [-1, 32, 641]             --
# ├─MaxPool1d: 1-5                              [-1, 32, 160]             --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-3                        [-1, 160, 32]             --
# |    |    └─SelfAttention: 3-1                [-1, 160, 32]             7,392
# |    |    └─BatchNorm1d: 3-2                  [-1, 160, 32]             320
# |    |    └─Dropout: 3-3                      [-1, 160, 32]             --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-4                        [-1, 160, 64]             --
# |    |    └─Linear: 3-4                       [-1, 160, 64]             2,112
# |    |    └─BatchNorm1d: 3-5                  [-1, 160, 64]             320
# |    |    └─ReLU: 3-6                         [-1, 160, 64]             --
# |    |    └─Dropout: 3-7                      [-1, 160, 64]             --
# ├─MaxPool1d: 1-6                              [-1, 64, 40]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-5                        [-1, 40, 64]              --
# |    |    └─SelfAttention: 3-8                [-1, 40, 64]              29,120
# |    |    └─BatchNorm1d: 3-9                  [-1, 40, 64]              80
# |    |    └─Dropout: 3-10                     [-1, 40, 64]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-6                        [-1, 40, 96]              --
# |    |    └─Linear: 3-11                      [-1, 40, 96]              6,240
# |    |    └─BatchNorm1d: 3-12                 [-1, 40, 96]              80
# |    |    └─ReLU: 3-13                        [-1, 40, 96]              --
# |    |    └─Dropout: 3-14                     [-1, 40, 96]              --
# ├─MaxPool1d: 1-7                              [-1, 96, 10]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-7                        [-1, 10, 96]              --
# |    |    └─SelfAttention: 3-15               [-1, 10, 96]              65,184
# |    |    └─BatchNorm1d: 3-16                 [-1, 10, 96]              20
# |    |    └─Dropout: 3-17                     [-1, 10, 96]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-8                        [-1, 10, 128]             --
# |    |    └─Linear: 3-18                      [-1, 10, 128]             12,416
# |    |    └─BatchNorm1d: 3-19                 [-1, 10, 128]             20
# |    |    └─ReLU: 3-20                        [-1, 10, 128]             --
# |    |    └─Dropout: 3-21                     [-1, 10, 128]             --
# ├─MaxPool1d: 1-8                              [-1, 128, 2]              --
# ├─Linear: 1-9                                 [-1, 1]                   257
# ===============================================================================================
# Total params: 134,521
# Trainable params: 134,521
# Non-trainable params: 0
# Total mult-adds (M): 125.46
# ===============================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 2.30
# Params size (MB): 0.51
# Estimated Total Size (MB): 2.90
# ===============================================================================================

# %% [markdown]
# ### Print out the model info

# %%
seperate = "\n" + "-" * 100 + "\n"
print(seperate + "Model infomation" + seperate)
print(f"Device used        :", device)
print(f"BATCH SIZE         :", BATCH_SIZE)
print(f"MAX_COUNT_F1_SCORE :", MAX_COUNT_F1_SCORE)
print(f"LEARNING RATE      :", LEARNING_RATE)
print(f"Prev Best f1-score in validation dataset:", prev_best_valid_f1)
print(f"Prev Best validation loss               :", prev_best_valid_loss)
print(f"Number of EPOCH for training   :",NUM_EPOCHS_CLASSIFIER, f"(EPOCH start from {EPOCH_START})")
print(f"Num of epochs of data for train:", num_train_data)
print(f"Num of epochs of data for valid:", num_valid_data)
print(f'Model parameters               : {sum(p.numel() for p in model.parameters()):,}' )
# Out:
# ----------------------------------------------------------------------------------------------------
# Model infomation
# ----------------------------------------------------------------------------------------------------
#
# Device used        : cuda
# BATCH SIZE         : 32
# MAX_COUNT_F1_SCORE : 20
# LEARNING RATE      : 0.001
# Prev Best f1-score in validation dataset: 0.625
# Prev Best validation loss               : 0.07256671259143192
# Number of EPOCH for training   : 101 (EPOCH start from 26)
# Num of epochs of data for train: 6345
# Num of epochs of data for valid: 1358
# Model parameters               : 134,521

# %% [markdown]
# ### Start Training Loop

# %%
# %%time
start_classification_model_training(EPOCH_START, NUM_EPOCHS_CLASSIFIER, 
                                    model, MODEL_FILE_DIRC_SateLight, "SateLight",
                                    df, prev_best_valid_f1, prev_best_valid_loss, 
                                    train_data, num_train_data, 
                                    valid_data, num_valid_data, 
                                    scheduler, optimizer, device)
# Out:
# > > > Epoch     : 26
# Train loss      : 0.01605148559438795
# Valid loss      : 0.11045271051580063
# Train precision : 0.8823529411764706
# Valid precision : 1.0
# Train accuracy  : 0.9982663514578408
# Valid accuracy  : 0.9948453608247423
# Train f1_score  : 0.8910891089108911
# Valid f1_score  : 0.5333333333333333
# Train recall    : 0.9
# Valid recall    : 0.36363636363636365
# > > > Epoch     : 27
# Train loss      : 0.02467666392001191
# Valid loss      : 0.12159415852657035
# Train precision : 0.8148148148148148
# Valid precision : 1.0
# Train accuracy  : 0.997478329393223
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.8461538461538461
# Valid f1_score  : 0.3076923076923077
# Train recall    : 0.88
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 28
# Train loss      : 0.003504307770729208
# Valid loss      : 0.19716880280761978
# Train precision : 0.9038461538461539
# Valid precision : 1.0
# Train accuracy  : 0.9987391646966115
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.9215686274509803
# Valid f1_score  : 0.3076923076923077
# Train recall    : 0.94
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 29
# Train loss      : 0.0007266872438340301
# Valid loss      : 0.13009660218618063
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 0.9998423955870764
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.98989898989899
# Valid f1_score  : 0.47058823529411764
# Train recall    : 0.98
# Valid recall    : 0.36363636363636365
# > > > Epoch     : 30
# Train loss      : 5.961598376195692e-05
# Valid loss      : 0.18976005882278724
# Train precision : 0.9803921568627451
# Valid precision : 0.75
# Train accuracy  : 0.9998423955870764
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.9900990099009901
# Valid f1_score  : 0.4
# Train recall    : 1.0
# Valid recall    : 0.2727272727272727
# > > > Epoch     : 31
# Train loss      : 0.006304297912735749
# Valid loss      : 0.1469777954662759
# Train precision : 0.96
# Valid precision : 0.75
# Train accuracy  : 0.9993695823483058
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.96
# Valid f1_score  : 0.4
# Train recall    : 0.96
# Valid recall    : 0.2727272727272727
# > > > Epoch     : 32
# Train loss      : 0.019773780228760918
# Valid loss      : 0.059449930363576035
# Train precision : 0.8979591836734694
# Valid precision : 0.45454545454545453
# Train accuracy  : 0.9982663514578408
# Valid accuracy  : 0.9911634756995582
# Train f1_score  : 0.8888888888888888
# Valid f1_score  : 0.45454545454545453
# Train recall    : 0.88
# Valid recall    : 0.45454545454545453
# > > > Epoch     : 33
# Train loss      : 0.005678611076796585
# Valid loss      : 0.1131514876880282
# Train precision : 0.9791666666666666
# Valid precision : 0.5714285714285714
# Train accuracy  : 0.9993695823483058
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 0.9591836734693877
# Valid f1_score  : 0.4444444444444444
# Train recall    : 0.94
# Valid recall    : 0.36363636363636365
# > > > Epoch     : 34
# Train loss      : 0.013459641473129155
# Valid loss      : 0.10740551173715956
# Train precision : 0.96
# Valid precision : 0.6666666666666666
# Train accuracy  : 0.9993695823483058
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.96
# Valid f1_score  : 0.47058823529411764
# Train recall    : 0.96
# Valid recall    : 0.36363636363636365
# > > > Epoch     : 35
# Train loss      : 0.0031461790986229907
# Valid loss      : 0.1504147517230921
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 0.9996847911741529
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.9795918367346939
# Valid f1_score  : 0.3076923076923077
# Train recall    : 0.96
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 36
# Train loss      : 1.555015102086246e-06
# Valid loss      : 0.1083215286961281
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9948453608247423
# Train f1_score  : 1.0
# Valid f1_score  : 0.5333333333333333
# Train recall    : 1.0
# Valid recall    : 0.36363636363636365
# > > > Epoch     : 37
# Train loss      : 5.552765778874459e-07
# Valid loss      : 0.12336593799755727
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9948453608247423
# Train f1_score  : 1.0
# Valid f1_score  : 0.5333333333333333
# Train recall    : 1.0
# Valid recall    : 0.36363636363636365
# > > > Epoch     : 38
# Train loss      : 9.58504397580065e-06
# Valid loss      : 0.1322581566897626
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9948453608247423
# Train f1_score  : 1.0
# Valid f1_score  : 0.5333333333333333
# Train recall    : 1.0
# Valid recall    : 0.36363636363636365
# > > > Epoch     : 39
# Train loss      : 9.725560191490224e-06
# Valid loss      : 0.15175421950022663
# Train precision : 0.9803921568627451
# Valid precision : 0.8
# Train accuracy  : 0.9998423955870764
# Valid accuracy  : 0.9941089837997055
# Train f1_score  : 0.9900990099009901
# Valid f1_score  : 0.5
# Train recall    : 1.0
# Valid recall    : 0.36363636363636365
# > > > Epoch     : 40
# Train loss      : 1.1010135239627764e-05
# Valid loss      : 0.13017975601710513
# Train precision : 1.0
# Valid precision : 0.75
# Train accuracy  : 1.0
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 1.0
# Valid f1_score  : 0.4
# Train recall    : 1.0
# Valid recall    : 0.2727272727272727
# > > > Epoch     : 41
# Train loss      : 5.7328892782397006e-05
# Valid loss      : 0.16557533650290063
# Train precision : 1.0
# Valid precision : 0.75
# Train accuracy  : 1.0
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 1.0
# Valid f1_score  : 0.4
# Train recall    : 1.0
# Valid recall    : 0.2727272727272727
# > > > Epoch     : 42
# Train loss      : 2.9287237327567834e-07
# Valid loss      : 0.18263118422631247
# Train precision : 1.0
# Valid precision : 0.75
# Train accuracy  : 1.0
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 1.0
# Valid f1_score  : 0.4
# Train recall    : 1.0
# Valid recall    : 0.2727272727272727
# > > > Epoch     : 43
# Train loss      : 9.621759110294342e-05
# Valid loss      : 0.14650035799749137
# Train precision : 0.9803921568627451
# Valid precision : 0.75
# Train accuracy  : 0.9998423955870764
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.9900990099009901
# Valid f1_score  : 0.4
# Train recall    : 1.0
# Valid recall    : 0.2727272727272727
# > > > Epoch     : 44
# Train loss      : 4.3023549605546275e-07
# Valid loss      : 0.1812400170322929
# Train precision : 1.0
# Valid precision : 0.75
# Train accuracy  : 1.0
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 1.0
# Valid f1_score  : 0.4
# Train recall    : 1.0
# Valid recall    : 0.2727272727272727
# > > > Epoch     : 45
# Train loss      : 0.005444102808973915
# Valid loss      : 0.21107056550093758
# Train precision : 0.98
# Valid precision : 1.0
# Train accuracy  : 0.9996847911741529
# Valid accuracy  : 0.9933726067746687
# Train f1_score  : 0.98
# Valid f1_score  : 0.3076923076923077
# Train recall    : 0.98
# Valid recall    : 0.18181818181818182
# The validation f1 score is not increasing for continuous 20 time, so training stop
# CPU times: total: 6min 38s
# Wall time: 9min 18s

# %% [markdown]
# ### Test the model performance on testing dataset

# %%
# Load the best model and turn to evaluation mode
model.eval()
state_dict_loaded = torch.load(f"{MODEL_FILE_DIRC_SateLight}/SateLight_best.pt")
model.load_state_dict(state_dict_loaded["model"])

test_loss, test_metric = evaluate_classifier(model, test_data, device, num_test_data) 

print("Best model is at epoch:",state_dict_loaded["epoch"])
print("Metric on testing dataset:")
for key, value in test_metric.items():
    print(f"{key:<10}: {value:.4f}")
# Out:
# Best model is at epoch: 7
# Metric on testing dataset:
# precision : 0.4444
# accuracy  : 0.9912
# f1_score  : 0.4000
# recall    : 0.3636

# %% [markdown]
# ## Build and Train the Simple CNN model

# %% [markdown]
# ### Build the CNN model

# %%
model      = CNN().to(device)
optimizer  = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  
scheduler  = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# Get the following information:
# 1. Previous Trained model (if exist)
# 2. df that store the training/validation loss & metrics
# 3. epoch where the training start
# 4. Previous Highest Validation Recall
# 5. Previous Lowest  Validation Loss
model, df, EPOCH_START, prev_best_valid_f1, prev_best_valid_loss = load_classification_model_dict(model, MODEL_FILE_DIRC_CNN, "CNN")

# Get the summary of the model
print(summary(model, (19,1280)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 32, 19]              --
# |    └─Conv1dWithInitialization: 2-1     [-1, 8, 1278]             --
# |    |    └─Conv1d: 3-1                  [-1, 8, 1278]             464
# |    └─BatchNorm1d: 2-2                  [-1, 8, 1278]             16
# |    └─ReLU: 2-3                         [-1, 8, 1278]             --
# |    └─MaxPool1d: 2-4                    [-1, 8, 319]              --
# |    └─Conv1dWithInitialization: 2-5     [-1, 16, 317]             --
# |    |    └─Conv1d: 3-2                  [-1, 16, 317]             400
# |    └─BatchNorm1d: 2-6                  [-1, 16, 317]             32
# |    └─ReLU: 2-7                         [-1, 16, 317]             --
# |    └─MaxPool1d: 2-8                    [-1, 16, 79]              --
# |    └─Conv1dWithInitialization: 2-9     [-1, 32, 77]              --
# |    |    └─Conv1d: 3-3                  [-1, 32, 77]              1,568
# |    └─BatchNorm1d: 2-10                 [-1, 32, 77]              64
# |    └─ReLU: 2-11                        [-1, 32, 77]              --
# |    └─MaxPool1d: 2-12                   [-1, 32, 19]              --
# ├─Linear: 1-2                            [-1, 1]                   609
# ==========================================================================================
# Total params: 3,153
# Trainable params: 3,153
# Non-trainable params: 0
# Total mult-adds (M): 0.83
# ==========================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 0.27
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.38
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 32, 19]              --
# |    └─Conv1dWithInitialization: 2-1     [-1, 8, 1278]             --
# |    |    └─Conv1d: 3-1                  [-1, 8, 1278]             464
# |    └─BatchNorm1d: 2-2                  [-1, 8, 1278]             16
# |    └─ReLU: 2-3                         [-1, 8, 1278]             --
# |    └─MaxPool1d: 2-4                    [-1, 8, 319]              --
# |    └─Conv1dWithInitialization: 2-5     [-1, 16, 317]             --
# |    |    └─Conv1d: 3-2                  [-1, 16, 317]             400
# |    └─BatchNorm1d: 2-6                  [-1, 16, 317]             32
# |    └─ReLU: 2-7                         [-1, 16, 317]             --
# |    └─MaxPool1d: 2-8                    [-1, 16, 79]              --
# |    └─Conv1dWithInitialization: 2-9     [-1, 32, 77]              --
# |    |    └─Conv1d: 3-3                  [-1, 32, 77]              1,568
# |    └─BatchNorm1d: 2-10                 [-1, 32, 77]              64
# |    └─ReLU: 2-11                        [-1, 32, 77]              --
# |    └─MaxPool1d: 2-12                   [-1, 32, 19]              --
# ├─Linear: 1-2                            [-1, 1]                   609
# ==========================================================================================
# Total params: 3,153
# Trainable params: 3,153
# Non-trainable params: 0
# Total mult-adds (M): 0.83
# ==========================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 0.27
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.38
# ==========================================================================================

# %% [markdown]
# ### Print out the model info

# %%
seperate = "\n" + "-" * 100 + "\n"
print(seperate + "Model infomation" + seperate)
print(f"Device used        :", device)
print(f"BATCH SIZE         :", BATCH_SIZE)
print(f"MAX_COUNT_F1_SCORE :", MAX_COUNT_F1_SCORE)
print(f"LEARNING RATE      :", LEARNING_RATE)
print(f"Prev Best recall in validation dataset:", prev_best_valid_f1)
print(f"Prev Best validation loss             :", prev_best_valid_loss)
print(f"Number of EPOCH for training   :",NUM_EPOCHS_CLASSIFIER, f"(EPOCH start from {EPOCH_START})")
print(f"Num of epochs of data for train:", num_train_data)
print(f"Num of epochs of data for valid:", num_valid_data)
print(f'Model parameters               : {sum(p.numel() for p in model.parameters()):,}' )
# Out:
# ----------------------------------------------------------------------------------------------------
# Model infomation
# ----------------------------------------------------------------------------------------------------
#
# Device used        : cuda
# BATCH SIZE         : 32
# MAX_COUNT_F1_SCORE : 20
# LEARNING RATE      : 0.001
# Prev Best recall in validation dataset: -1
# Prev Best validation loss             : 10000
# Number of EPOCH for training   : 101 (EPOCH start from 1)
# Num of epochs of data for train: 6345
# Num of epochs of data for valid: 1358
# Model parameters               : 3,153

# %% [markdown]
# ### Start Training Loop

# %%
# %%time
start_classification_model_training(EPOCH_START, NUM_EPOCHS_CLASSIFIER, 
                                    model, MODEL_FILE_DIRC_CNN, "CNN",
                                    df, prev_best_valid_f1, prev_best_valid_loss, 
                                    train_data, num_train_data, 
                                    valid_data, num_valid_data, 
                                    scheduler, optimizer, device)
# Out:
# > > > Epoch     : 1
# Train loss      : 0.1091184768549822
# Valid loss      : 0.07955073616405695
# Train precision : 0.01
# Valid precision : 1.0
# Train accuracy  : 0.9766745468873128
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 0.013333333333333334
# Valid f1_score  : 0.16666666666666666
# Train recall    : 0.02
# Valid recall    : 0.09090909090909091
# > > > Epoch     : 2
# Train loss      : 0.059958299165929194
# Valid loss      : 0.08894044124803867
# Train precision : 0.5454545454545454
# Valid precision : 1.0
# Train accuracy  : 0.9922773837667455
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 0.19672131147540983
# Valid f1_score  : 0.16666666666666666
# Train recall    : 0.12
# Valid recall    : 0.09090909090909091
# > > > Epoch     : 3
# Train loss      : 0.04167339899111172
# Valid loss      : 0.06574114996409085
# Train precision : 0.7391304347826086
# Valid precision : 0.6666666666666666
# Train accuracy  : 0.9938534278959811
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 0.4657534246575342
# Valid f1_score  : 0.2857142857142857
# Train recall    : 0.34
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 4
# Train loss      : 0.03538759941641767
# Valid loss      : 0.0567380551532369
# Train precision : 0.8
# Valid precision : 0.4
# Train accuracy  : 0.9959022852639874
# Valid accuracy  : 0.9911634756995582
# Train f1_score  : 0.7111111111111111
# Valid f1_score  : 0.25
# Train recall    : 0.64
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 5
# Train loss      : 0.01994176831030153
# Valid loss      : 0.10555258401339433
# Train precision : 0.7450980392156863
# Valid precision : 0.5
# Train accuracy  : 0.996059889676911
# Valid accuracy  : 0.991899852724595
# Train f1_score  : 0.7524752475247525
# Valid f1_score  : 0.15384615384615385
# Train recall    : 0.76
# Valid recall    : 0.09090909090909091
# > > > Epoch     : 6
# Train loss      : 0.020302881758606502
# Valid loss      : 0.03403737592073336
# Train precision : 0.8333333333333334
# Valid precision : 0.3333333333333333
# Train accuracy  : 0.9965327029156816
# Valid accuracy  : 0.9896907216494846
# Train f1_score  : 0.7608695652173914
# Valid f1_score  : 0.3
# Train recall    : 0.7
# Valid recall    : 0.2727272727272727
# > > > Epoch     : 7
# Train loss      : 0.013865697791196636
# Valid loss      : 0.07456632607375767
# Train precision : 0.7843137254901961
# Valid precision : 0.4
# Train accuracy  : 0.9966903073286052
# Valid accuracy  : 0.9911634756995582
# Train f1_score  : 0.7920792079207921
# Valid f1_score  : 0.25
# Train recall    : 0.8
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 8
# Train loss      : 0.012629718605866157
# Valid loss      : 0.047404173063457185
# Train precision : 0.9523809523809523
# Valid precision : 0.4
# Train accuracy  : 0.9981087470449173
# Valid accuracy  : 0.9911634756995582
# Train f1_score  : 0.8695652173913043
# Valid f1_score  : 0.25
# Train recall    : 0.8
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 9
# Train loss      : 0.008251165502489647
# Valid loss      : 0.07870650177167474
# Train precision : 0.9183673469387755
# Valid precision : 0.4
# Train accuracy  : 0.9985815602836879
# Valid accuracy  : 0.9911634756995582
# Train f1_score  : 0.9090909090909091
# Valid f1_score  : 0.25
# Train recall    : 0.9
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 10
# Train loss      : 0.006086829918109386
# Valid loss      : 0.06090221735583552
# Train precision : 0.9777777777777777
# Valid precision : 0.4
# Train accuracy  : 0.9988967691095351
# Valid accuracy  : 0.9911634756995582
# Train f1_score  : 0.9263157894736842
# Valid f1_score  : 0.25
# Train recall    : 0.88
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 11
# Train loss      : 0.002405350212638642
# Valid loss      : 0.07234626363756119
# Train precision : 1.0
# Valid precision : 0.4
# Train accuracy  : 0.9993695823483058
# Valid accuracy  : 0.9911634756995582
# Train f1_score  : 0.9583333333333334
# Valid f1_score  : 0.25
# Train recall    : 0.92
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 12
# Train loss      : 0.0025327226632578157
# Valid loss      : 0.08320501257081836
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 0.9996847911741529
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 0.9795918367346939
# Valid f1_score  : 0.2857142857142857
# Train recall    : 0.96
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 13
# Train loss      : 0.0017254858930280832
# Valid loss      : 0.07280311002836677
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 0.9998423955870764
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 0.98989898989899
# Valid f1_score  : 0.2857142857142857
# Train recall    : 0.98
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 14
# Train loss      : 0.0010587993035550906
# Valid loss      : 0.07600162992438338
# Train precision : 1.0
# Valid precision : 0.5
# Train accuracy  : 0.9998423955870764
# Valid accuracy  : 0.991899852724595
# Train f1_score  : 0.98989898989899
# Valid f1_score  : 0.26666666666666666
# Train recall    : 0.98
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 15
# Train loss      : 0.0015127131987350806
# Valid loss      : 0.08219305583598097
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 0.9996847911741529
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 0.9795918367346939
# Valid f1_score  : 0.2857142857142857
# Train recall    : 0.96
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 16
# Train loss      : 0.0007936744638780129
# Valid loss      : 0.06670260214416888
# Train precision : 1.0
# Valid precision : 0.5
# Train accuracy  : 0.9998423955870764
# Valid accuracy  : 0.991899852724595
# Train f1_score  : 0.98989898989899
# Valid f1_score  : 0.26666666666666666
# Train recall    : 0.98
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 17
# Train loss      : 0.0001749862234249518
# Valid loss      : 0.08445318159330101
# Train precision : 0.9803921568627451
# Valid precision : 0.6666666666666666
# Train accuracy  : 0.9998423955870764
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 0.9900990099009901
# Valid f1_score  : 0.2857142857142857
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 18
# Train loss      : 0.00012718282102488297
# Valid loss      : 0.10888210445469648
# Train precision : 1.0
# Valid precision : 0.5
# Train accuracy  : 1.0
# Valid accuracy  : 0.991899852724595
# Train f1_score  : 1.0
# Valid f1_score  : 0.15384615384615385
# Train recall    : 1.0
# Valid recall    : 0.09090909090909091
# > > > Epoch     : 19
# Train loss      : 5.787523519145024e-05
# Valid loss      : 0.08239139795838014
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 1.0
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 1.0
# Valid f1_score  : 0.2857142857142857
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 20
# Train loss      : 5.3234296313551575e-05
# Valid loss      : 0.0871618731264217
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 1.0
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 1.0
# Valid f1_score  : 0.2857142857142857
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 21
# Train loss      : 3.092709564815504e-05
# Valid loss      : 0.09496758961167054
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 1.0
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 1.0
# Valid f1_score  : 0.2857142857142857
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 22
# Train loss      : 2.0930719081122705e-05
# Valid loss      : 0.09384106669529499
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 1.0
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 1.0
# Valid f1_score  : 0.2857142857142857
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 23
# Train loss      : 2.234448536873081e-05
# Valid loss      : 0.08949077028733447
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 1.0
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 1.0
# Valid f1_score  : 0.2857142857142857
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 24
# Train loss      : 1.6274273256062407e-05
# Valid loss      : 0.09062443528337728
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 1.0
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 1.0
# Valid f1_score  : 0.2857142857142857
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 25
# Train loss      : 2.165336153088769e-05
# Valid loss      : 0.08401606342248105
# Train precision : 1.0
# Valid precision : 0.6666666666666666
# Train accuracy  : 1.0
# Valid accuracy  : 0.9926362297496318
# Train f1_score  : 1.0
# Valid f1_score  : 0.2857142857142857
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# > > > Epoch     : 26
# Train loss      : 1.965926807963453e-05
# Valid loss      : 0.085435576582621
# Train precision : 1.0
# Valid precision : 0.5
# Train accuracy  : 1.0
# Valid accuracy  : 0.991899852724595
# Train f1_score  : 1.0
# Valid f1_score  : 0.26666666666666666
# Train recall    : 1.0
# Valid recall    : 0.18181818181818182
# The validation f1 score is not increasing for continuous 20 time, so training stop
# CPU times: total: 1min 10s
# Wall time: 4min 29s

# %% [markdown]
# ### Test the model performance on testing dataset

# %%
# Load the best model and turn to evaluation mode
model.eval()
state_dict_loaded = torch.load(f"{MODEL_FILE_DIRC_CNN}/CNN_best.pt")
model.load_state_dict(state_dict_loaded["model"])

test_loss, test_metric = evaluate_classifier(model, test_data, device, num_test_data) 

print("Best model is at epoch:",state_dict_loaded["epoch"])
print("Metric on testing dataset:")
for key, value in test_metric.items():
    print(f"{key:<10}: {value:.4f}")
# Out:
# Best model is at epoch: 6
# Metric on testing dataset:
# precision : 0.3333
# accuracy  : 0.9867
# f1_score  : 0.4375
# recall    : 0.6364
